# %% [markdown]
# # Introduction to Spark

# %% [markdown]
# ## Basic initialization

# %% [markdown]
# `SparkSession` is used to connect to the Spark Cluster.

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# We will use Pandas to operate on the reduced data in the *driver program*.

# %%
import pandas as pd

# %% [markdown]
# Numpy will be always useful.

# %%
import numpy as np

# %% [markdown]
# Create a new session (or reuse an existing one).

# %%
spark = SparkSession.builder.getOrCreate()

# %%
print(spark)
# Out:
# <pyspark.sql.session.SparkSession object at 0x7f7a5c779128>

# %% [markdown]
# We can see that the session is established.

# %% [markdown]
# ## Using basic operations on RDD

# %% [markdown]
# Obtain a `sparkContext` to interact with RDDs.

# %%
sc = spark.sparkContext

# %% [markdown]
# Load a text file into and RDD.

# %%
lines = sc.textFile("airports.csv")

# %% [markdown]
# Perform a *transformation* on the RDD.

# %%
lineLengths = lines.map(lambda s: len(s))

# %% [markdown]
# Perform an *action* on the RDD.

# %%
totalLength = lineLengths.reduce(lambda a, b: a + b)

# %% [markdown]
# The result is computed:

# %%
totalLength
# Out:
# 23504

# %% [markdown]
# Perform another *action* on the RDD.

# %%
maxLength = lineLengths.reduce(lambda a, b: max(a, b))

# %%
maxLength
# Out:
# 115

# %% [markdown]
# ## Creating Spark Data Frames from Pandas

# %% [markdown]
# We can list the tables in our Spark Session, currently empty.

# %%
print(spark.catalog.listTables())
# Out:
# []

# %% [markdown]
# We can create a Pandas `DataFrame` with random values.

# %%
pd_temp = pd.DataFrame(np.random.random(100))

# %% [markdown]
# We can see on the plot that it is really random:

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')

# %%
pd_temp.plot()

# %% [markdown]
# Now we can convert it into Spark DataFrame:

# %%
spark_temp = spark.createDataFrame(pd_temp)

# %% [markdown]
# `createOrReplaceTempView` creates (or replaces if that view name already exists) a lazily evaluated "view" that you can then use like a table in Spark SQL.
#
# It does not persist to memory unless you cache (persist) the dataset that underpins the view.

# %%
spark_temp.createOrReplaceTempView("temp")

# %% [markdown]
# The created view is `TEMPORARY` which means it is not persistent.

# %%
print(spark.catalog.listTables())
# Out:
# [Table(name='temp', database=None, description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
spark_temp.show()
# Out:
# +--------------------+
# |                   0|
# +--------------------+
# |  0.9257419964439909|
# |  0.3797480033664562|
# |  0.7752884510360875|
# |   0.851582947087418|
# | 0.31500494691975955|
# |  0.9774216468608424|
# | 0.11300408908050008|
# |  0.8283381313856946|
# |  0.9203607503555741|
# | 0.24036444400170964|
# |   0.813975985610506|
# |  0.8826750752218666|
# |  0.4722777051909919|
# | 0.39492103107773213|
# |0.056856962103340014|
# |  0.0180468387773699|
# | 0.30346677368583885|
# |  0.8176770104030631|
# |  0.6084849316611631|
# |  0.6651440096534087|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# We can now use transformations on this DataFrame. The transformations are translated (compiled) to RDD transformations.

# %%
from pyspark.sql.functions import col, asc

# %%
spark_temp.filter((col('0') > 0.9)).show()
# Out:
# +------------------+
# |                 0|
# +------------------+
# |0.9257419964439909|
# |0.9774216468608424|
# |0.9203607503555741|
# | 0.962164095941912|
# |0.9086523394790169|
# | 0.913586607132326|
# |0.9188739649941245|
# |0.9223865645212491|
# +------------------+

# %% [markdown]
# ## Creating Spark Data Frames from input files

# %%
file_path = "airports.csv"

# Read in the airports data
airports = spark.read.csv(file_path,header=True)

# Show the data
print(airports.show())
# Out:
# +---------+--------------------+-------------+-----+-------+--------+----------+
# |IATA_CODE|             AIRPORT|         CITY|STATE|COUNTRY|LATITUDE| LONGITUDE|
# +---------+--------------------+-------------+-----+-------+--------+----------+
# |      ABE|Lehigh Valley Int...|    Allentown|   PA|    USA|40.65236| -75.44040|
# |      ABI|Abilene Regional ...|      Abilene|   TX|    USA|32.41132| -99.68190|
# |      ABQ|Albuquerque Inter...|  Albuquerque|   NM|    USA|35.04022|-106.60919|
# |      ABR|Aberdeen Regional...|     Aberdeen|   SD|    USA|45.44906| -98.42183|
# |      ABY|Southwest Georgia...|       Albany|   GA|    USA|31.53552| -84.19447|
# |      ACK|Nantucket Memoria...|    Nantucket|   MA|    USA|41.25305| -70.06018|
# |      ACT|Waco Regional Air...|         Waco|   TX|    USA|31.61129| -97.23052|
# |      ACV|      Arcata Airport|Arcata/Eureka|   CA|    USA|40.97812|-124.10862|
# |      ACY|Atlantic City Int...|Atlantic City|   NJ|    USA|39.45758| -74.57717|
# |      ADK|        Adak Airport|         Adak|   AK|    USA|51.87796|-176.64603|
# |      ADQ|      Kodiak Airport|       Kodiak|   AK|    USA|57.74997|-152.49386|
# |      AEX|Alexandria Intern...|   Alexandria|   LA|    USA|31.32737| -92.54856|
# |      AGS|Augusta Regional ...|      Augusta|   GA|    USA|33.36996| -81.96450|
# |      AKN| King Salmon Airport|  King Salmon|   AK|    USA|58.67680|-156.64922|
# |      ALB|Albany Internatio...|       Albany|   NY|    USA|42.74812| -73.80298|
# |      ALO|Waterloo Regional...|     Waterloo|   IA|    USA|42.55708| -92.40034|
# |      AMA|Rick Husband Amar...|     Amarillo|   TX|    USA|35.21937|-101.70593|
# |      ANC|Ted Stevens Ancho...|    Anchorage|   AK|    USA|61.17432|-149.99619|
# |      APN|Alpena County Reg...|       Alpena|   MI|    USA|45.07807| -83.56029|
# |      ASE|Aspen-Pitkin Coun...|        Aspen|   CO|    USA|39.22316|-106.86885|
# +---------+--------------------+-------------+-----+-------+--------+----------+
# only showing top 20 rows
#
# None

# %% [markdown]
# It may be useful to convert them to Pandas for quick browsing.
#
# **Warning!** This is not efficient for large datasets, as it requires performing actions on the dataset.

# %%
airports.toPandas()
# Out:
#     IATA_CODE                                            AIRPORT  \
# 0         ABE                Lehigh Valley International Airport
# 1         ABI                           Abilene Regional Airport
# 2         ABQ                  Albuquerque International Sunport
# 3         ABR                          Aberdeen Regional Airport
# 4         ABY                 Southwest Georgia Regional Airport
# 5         ACK                         Nantucket Memorial Airport
# 6         ACT                              Waco Regional Airport
# 7         ACV                                     Arcata Airport
# 8         ACY                Atlantic City International Airport
# 9         ADK                                       Adak Airport
# 10        ADQ                                     Kodiak Airport
# 11        AEX                   Alexandria International Airport
# 12        AGS              Augusta Regional Airport (Bush Field)
# 13        AKN                                King Salmon Airport
# 14        ALB                       Albany International Airport
# 15        ALO                          Waterloo Regional Airport
# 16        AMA        Rick Husband Amarillo International Airport
# 17        ANC        Ted Stevens Anchorage International Airport
# 18        APN                     Alpena County Regional Airport
# 19        ASE                        Aspen-Pitkin County Airport
# 20        ATL   Hartsfield-Jackson Atlanta International Airport
# 21        ATW                     Appleton International Airport
# 22        AUS             Austin-Bergstrom International Airport
# 23        AVL                         Asheville Regional Airport
# 24        AVP        Wilkes-Barre/Scranton International Airport
# 25        AZO       Kalamazoo/Battle Creek International Airport
# 26        BDL                      Bradley International Airport
# 27        BET                                     Bethel Airport
# 28        BFL                                      Meadows Field
# 29        BGM                         Greater Binghamton Airport
# ..        ...                                                ...
# 292       SRQ           Sarasota-Bradenton International Airport
# 293       STC                         St. Cloud Regional Airport
# 294       STL   St. Louis International Airport at Lambert Field
# 295       STT                              Cyril E. King Airport
# 296       STX                           Henry E. Rohlsen Airport
# 297       SUN                          Friedman Memorial Airport
# 298       SUX                              Sioux Gateway Airport
# 299       SWF                      Stewart International Airport
# 300       SYR             Syracuse Hancock International Airport
# 301       TLH                  Tallahassee International Airport
# 302       TOL                             Toledo Express Airport
# 303       TPA                        Tampa International Airport
# 304       TRI                        Tri-Cities Regional Airport
# 305       TTN                             Trenton Mercer Airport
# 306       TUL                        Tulsa International Airport
# 307       TUS                       Tucson International Airport
# 308       TVC                             Cherry Capital Airport
# 309       TWF       Magic Valley Regional Airport (Joslin Field)
# 310       TXK            Texarkana Regional Airport (Webb Field)
# 311       TYR                      Tyler Pounds Regional Airport
# 312       TYS                               McGhee Tyson Airport
# 313       UST  Northeast Florida Regional Airport (St. August...
# 314       VEL                                     Valdez Airport
# 315       VLD                          Valdosta Regional Airport
# 316       VPS         Destin-Fort Walton Beach Airport/Eglin AFB
# 317       WRG                                   Wrangell Airport
# 318       WYS                             Westerly State Airport
# 319       XNA                Northwest Arkansas Regional Airport
# 320       YAK                                    Yakutat Airport
# 321       YUM                         Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE   LONGITUDE
# 0                         Allentown    PA     USA  40.65236   -75.44040
# 1                           Abilene    TX     USA  32.41132   -99.68190
# 2                       Albuquerque    NM     USA  35.04022  -106.60919
# 3                          Aberdeen    SD     USA  45.44906   -98.42183
# 4                            Albany    GA     USA  31.53552   -84.19447
# 5                         Nantucket    MA     USA  41.25305   -70.06018
# 6                              Waco    TX     USA  31.61129   -97.23052
# 7                     Arcata/Eureka    CA     USA  40.97812  -124.10862
# 8                     Atlantic City    NJ     USA  39.45758   -74.57717
# 9                              Adak    AK     USA  51.87796  -176.64603
# 10                           Kodiak    AK     USA  57.74997  -152.49386
# 11                       Alexandria    LA     USA  31.32737   -92.54856
# 12                          Augusta    GA     USA  33.36996   -81.96450
# 13                      King Salmon    AK     USA  58.67680  -156.64922
# 14                           Albany    NY     USA  42.74812   -73.80298
# 15                         Waterloo    IA     USA  42.55708   -92.40034
# 16                         Amarillo    TX     USA  35.21937  -101.70593
# 17                        Anchorage    AK     USA  61.17432  -149.99619
# 18                           Alpena    MI     USA  45.07807   -83.56029
# 19                            Aspen    CO     USA  39.22316  -106.86885
# 20                          Atlanta    GA     USA  33.64044   -84.42694
# 21                         Appleton    WI     USA  44.25741   -88.51948
# 22                           Austin    TX     USA  30.19453   -97.66987
# 23                        Asheville    NC     USA  35.43619   -82.54181
# 24            Wilkes-Barre/Scranton    PA     USA  41.33815   -75.72427
# 25                        Kalamazoo    MI     USA  42.23488   -85.55206
# 26                    Windsor Locks    CT     USA  41.93887   -72.68323
# 27                           Bethel    AK     USA  60.77978  -161.83800
# 28                      Bakersfield    CA     USA  35.43360  -119.05677
# 29                       Binghamton    NY     USA  42.20848   -75.97961
# ..                              ...   ...     ...       ...         ...
# 292                        Sarasota    FL     USA  27.39533   -82.55411
# 293                        St Cloud    MN     USA  45.54532   -94.05834
# 294                        St Louis    MO     USA  38.74769   -90.35999
# 295                Charlotte Amalie    VI     USA  18.33731   -64.97336
# 296                   Christiansted    VI     USA  17.70189   -64.79856
# 297                          Hailey    ID     USA  43.50484  -114.29659
# 298                      Sioux City    IA     USA  42.40260   -96.38437
# 299                        Newburgh    NY     USA  41.50409   -74.10484
# 300                        Syracuse    NY     USA  43.11119   -76.10631
# 301                     Tallahassee    FL     USA  30.39653   -84.35033
# 302                          Toledo    OH     USA  41.58681   -83.80783
# 303                           Tampa    FL     USA  27.97547   -82.53325
# 304                         Bristol    TN     USA  36.47521   -82.40742
# 305                         Trenton    NJ     USA  40.27669   -74.81347
# 306                           Tulsa    OK     USA  36.19837   -95.88824
# 307                          Tucson    AZ     USA  32.11608  -110.94103
# 308                   Traverse City    MI     USA  44.74144   -85.58224
# 309                      Twin Falls    ID     USA  42.48180  -114.48774
# 310                       Texarkana    AR     USA  33.45371   -93.99102
# 311                           Tyler    TX     USA  32.35414   -95.40239
# 312                       Knoxville    TN     USA  35.81249   -83.99286
# 313                   St. Augustine    FL     USA      None        None
# 314                          Vernal    UT     USA  40.44090  -109.50992
# 315                        Valdosta    GA     USA  30.78250   -83.27672
# 316                      Valparaiso    FL     USA  30.48325   -86.52540
# 317                        Wrangell    AK     USA  56.48433  -132.36982
# 318                West Yellowstone    MT     USA  44.68840  -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187   -94.30681
# 320                         Yakutat    AK     USA  59.50336  -139.66023
# 321                            Yuma    AZ     USA  32.65658  -114.60597
#
# [322 rows x 7 columns]

# %% [markdown]
# ### Running SQL queries on dataframes

# %%
airports.createOrReplaceTempView("airports")

# %%
# Get the first 10 rows of flights
query = "FROM airports SELECT * LIMIT 10"

airports10 = spark.sql(query)

# Show the results
airports10.show()
# Out:
# +---------+--------------------+-------------+-----+-------+--------+----------+
# |IATA_CODE|             AIRPORT|         CITY|STATE|COUNTRY|LATITUDE| LONGITUDE|
# +---------+--------------------+-------------+-----+-------+--------+----------+
# |      ABE|Lehigh Valley Int...|    Allentown|   PA|    USA|40.65236| -75.44040|
# |      ABI|Abilene Regional ...|      Abilene|   TX|    USA|32.41132| -99.68190|
# |      ABQ|Albuquerque Inter...|  Albuquerque|   NM|    USA|35.04022|-106.60919|
# |      ABR|Aberdeen Regional...|     Aberdeen|   SD|    USA|45.44906| -98.42183|
# |      ABY|Southwest Georgia...|       Albany|   GA|    USA|31.53552| -84.19447|
# |      ACK|Nantucket Memoria...|    Nantucket|   MA|    USA|41.25305| -70.06018|
# |      ACT|Waco Regional Air...|         Waco|   TX|    USA|31.61129| -97.23052|
# |      ACV|      Arcata Airport|Arcata/Eureka|   CA|    USA|40.97812|-124.10862|
# |      ACY|Atlantic City Int...|Atlantic City|   NJ|    USA|39.45758| -74.57717|
# |      ADK|        Adak Airport|         Adak|   AK|    USA|51.87796|-176.64603|
# +---------+--------------------+-------------+-----+-------+--------+----------+

# %% [markdown]
# ### More complex examples
#
# Read data from CSV file:
#  * `inferSchema` - to detect which columns are numbers (not strigs!) - useful e.g. for sorting.
#  * `header` - to read the firs line as column names

# %%
countries = spark.read.csv("countries of the world.csv",inferSchema=True,header=True)

# %%
countries.toPandas()
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# 11              Australia   OCEANIA                                20264082
# 12                Austria   WESTERN EUROPE                          8192880
# 13             Azerbaijan                  C.W. OF IND. STATES      7961619
# 14           Bahamas, The               LATIN AMER. & CARIB          303770
# 15                Bahrain   NEAR EAST                                698585
# 16             Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 17               Barbados               LATIN AMER. & CARIB          279912
# 18                Belarus                  C.W. OF IND. STATES     10293011
# 19                Belgium   WESTERN EUROPE                         10379067
# 20                 Belize               LATIN AMER. & CARIB          287730
# 21                  Benin   SUB-SAHARAN AFRICA                      7862944
# 22                Bermuda   NORTHERN AMERICA                          65773
# 23                 Bhutan         ASIA (EX. NEAR EAST)              2279723
# 24                Bolivia               LATIN AMER. & CARIB         8989046
# 25   Bosnia & Herzegovina   EASTERN EUROPE                          4498976
# 26               Botswana   SUB-SAHARAN AFRICA                      1639833
# 27                 Brazil               LATIN AMER. & CARIB       188078227
# 28     British Virgin Is.               LATIN AMER. & CARIB           23098
# 29                 Brunei         ASIA (EX. NEAR EAST)               379444
# ..                     ...                                  ...         ...
# 197                 Syria   NEAR EAST                              18881361
# 198                Taiwan         ASIA (EX. NEAR EAST)             23036087
# 199            Tajikistan                  C.W. OF IND. STATES      7320815
# 200              Tanzania   SUB-SAHARAN AFRICA                     37445392
# 201              Thailand         ASIA (EX. NEAR EAST)             64631595
# 202                  Togo   SUB-SAHARAN AFRICA                      5548702
# 203                 Tonga   OCEANIA                                  114689
# 204     Trinidad & Tobago               LATIN AMER. & CARIB         1065842
# 205               Tunisia   NORTHERN AFRICA                        10175014
# 206                Turkey   NEAR EAST                              70413958
# 207          Turkmenistan                  C.W. OF IND. STATES      5042920
# 208     Turks & Caicos Is               LATIN AMER. & CARIB           21152
# 209                Tuvalu   OCEANIA                                   11810
# 210                Uganda   SUB-SAHARAN AFRICA                     28195754
# 211               Ukraine                  C.W. OF IND. STATES     46710816
# 212  United Arab Emirates   NEAR EAST                               2602713
# 213        United Kingdom   WESTERN EUROPE                         60609153
# 214         United States   NORTHERN AMERICA                      298444215
# 215               Uruguay               LATIN AMER. & CARIB         3431932
# 216            Uzbekistan                  C.W. OF IND. STATES     27307134
# 217               Vanuatu   OCEANIA                                  208869
# 218             Venezuela               LATIN AMER. & CARIB        25730435
# 219               Vietnam         ASIA (EX. NEAR EAST)             84402966
# 220        Virgin Islands               LATIN AMER. & CARIB          108605
# 221     Wallis and Futuna   OCEANIA                                   16025
# 222             West Bank   NEAR EAST                               2460492
# 223        Western Sahara   NORTHERN AFRICA                          273008
# 224                 Yemen   NEAR EAST                              21456188
# 225                Zambia   SUB-SAHARAN AFRICA                     11502010
# 226              Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0            647500                       48,0                         0,00
# 1             28748                      124,6                         1,26
# 2           2381740                       13,8                         0,04
# 3               199                      290,4                        58,29
# 4               468                      152,1                         0,00
# 5           1246700                        9,7                         0,13
# 6               102                      132,1                        59,80
# 7               443                      156,0                        34,54
# 8           2766890                       14,4                         0,18
# 9             29800                       99,9                         0,00
# 10              193                      372,5                        35,49
# 11          7686850                        2,6                         0,34
# 12            83870                       97,7                         0,00
# 13            86600                       91,9                         0,00
# 14            13940                       21,8                        25,41
# 15              665                     1050,5                        24,21
# 16           144000                     1023,4                         0,40
# 17              431                      649,5                        22,51
# 18           207600                       49,6                         0,00
# 19            30528                      340,0                         0,22
# 20            22966                       12,5                         1,68
# 21           112620                       69,8                         0,11
# 22               53                     1241,0                       194,34
# 23            47000                       48,5                         0,00
# 24          1098580                        8,2                         0,00
# 25            51129                       88,0                         0,04
# 26           600370                        2,7                         0,00
# 27          8511965                       22,1                         0,09
# 28              153                      151,0                        52,29
# 29             5770                       65,8                         2,79
# ..              ...                        ...                          ...
# 197          185180                      102,0                         0,10
# 198           35980                      640,3                         4,35
# 199          143100                       51,2                         0,00
# 200          945087                       39,6                         0,15
# 201          514000                      125,7                         0,63
# 202           56785                       97,7                         0,10
# 203             748                      153,3                        56,02
# 204            5128                      207,9                         7,06
# 205          163610                       62,2                         0,70
# 206          780580                       90,2                         0,92
# 207          488100                       10,3                         0,00
# 208             430                       49,2                        90,47
# 209              26                      454,2                        92,31
# 210          236040                      119,5                         0,00
# 211          603700                       77,4                         0,46
# 212           82880                       31,4                         1,59
# 213          244820                      247,6                         5,08
# 214         9631420                       31,0                         0,21
# 215          176220                       19,5                         0,37
# 216          447400                       61,0                         0,00
# 217           12200                       17,1                        20,72
# 218          912050                       28,2                         0,31
# 219          329560                      256,1                         1,05
# 220            1910                       56,9                         9,84
# 221             274                       58,5                        47,08
# 222            5860                      419,9                         0,00
# 223          266000                        1,0                         0,42
# 224          527970                       40,6                         0,36
# 225          752614                       15,3                         0,00
# 226          390580                       31,3                         0,00
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0           23,06                             163,07               700.0
# 1           -4,93                              21,52              4500.0
# 2           -0,39                                 31              6000.0
# 3          -20,71                               9,27              8000.0
# 4             6,6                               4,05             19000.0
# 5               0                             191,19              1900.0
# 6           10,76                              21,03              8600.0
# 7           -6,15                              19,46             11000.0
# 8            0,61                              15,18             11200.0
# 9           -6,47                              23,28              3500.0
# 10              0                               5,89             28000.0
# 11           3,98                               4,69             29000.0
# 12              2                               4,66             30000.0
# 13           -4,9                              81,74              3400.0
# 14           -2,2                              25,21             16700.0
# 15           1,05                              17,27             16900.0
# 16          -0,71                               62,6              1900.0
# 17          -0,31                               12,5             15700.0
# 18           2,54                              13,37              6100.0
# 19           1,23                               4,68             29100.0
# 20              0                              25,69              4900.0
# 21              0                                 85              1100.0
# 22           2,49                               8,53             36000.0
# 23              0                             100,44              1300.0
# 24          -1,32                              53,11              2400.0
# 25           0,31                              21,05              6100.0
# 26              0                              54,58              9000.0
# 27          -0,03                              29,61              7600.0
# 28          10,01                              18,05             16000.0
# 29           3,59                              12,61             18600.0
# ..            ...                                ...                 ...
# 197             0                              29,53              3300.0
# 198             0                                6,4             23400.0
# 199         -2,86                             110,76              1000.0
# 200         -2,06                              98,54               600.0
# 201             0                              20,48              7400.0
# 202             0                              66,61              1500.0
# 203             0                              12,62              2200.0
# 204        -10,83                              24,31              9500.0
# 205         -0,57                              24,77              6900.0
# 206             0                              41,04              6700.0
# 207         -0,86                              73,08              5800.0
# 208         11,68                              15,67              9600.0
# 209             0                              20,03              1100.0
# 210             0                              67,83              1400.0
# 211         -0,39                              20,34              5400.0
# 212          1,03                              14,51             23200.0
# 213          2,19                               5,16             27700.0
# 214          3,41                                6,5             37800.0
# 215         -0,32                              11,95             12800.0
# 216         -1,72                               71,1              1700.0
# 217             0                              55,16              2900.0
# 218         -0,04                               22,2              4800.0
# 219         -0,45                              25,95              2500.0
# 220         -8,94                               8,03             17200.0
# 221          None                               None              3700.0
# 222          2,98                              19,62               800.0
# 223          None                               None                 NaN
# 224             0                               61,5               800.0
# 225             0                              88,29               800.0
# 226             0                              67,69              1900.0
#
#     Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0           36,0               3,2      12,13      0,22     87,65       1
# 1           86,5              71,2      21,09      4,42     74,49       3
# 2           70,0              78,1       3,22      0,25     96,53       1
# 3           97,0             259,5         10        15        75       2
# 4          100,0             497,2       2,22         0     97,78       3
# 5           42,0               7,8       2,41      0,24     97,35    None
# 6           95,0             460,0          0         0       100       2
# 7           89,0             549,9      18,18      4,55     77,27       2
# 8           97,1             220,4      12,31      0,48     87,21       3
# 9           98,6             195,7      17,55       2,3     80,15       4
# 10          97,0             516,1      10,53         0     89,47       2
# 11         100,0             565,5       6,55      0,04     93,41       1
# 12          98,0             452,2      16,91      0,86     82,23       3
# 13          97,0             137,1      19,63      2,71     77,66       1
# 14          95,6             460,6        0,8       0,4      98,8       2
# 15          89,1             281,3       2,82      5,63     91,55       1
# 16          43,1               7,3      62,11      3,07     34,82       2
# 17          97,4             481,9      37,21      2,33     60,46       2
# 18          99,6             319,1      29,55       0,6     69,85       4
# 19          98,0             462,6      23,28       0,4     76,32       3
# 20          94,1             115,7       2,85      1,71     95,44       2
# 21          40,9               9,7      18,08       2,4     79,52       2
# 22          98,0             851,4         20         0        80       2
# 23          42,2              14,3       3,09      0,43     96,48       2
# 24          87,2              71,9       2,67      0,19     97,14     1,5
# 25          None             215,4       13,6      2,96     83,44       4
# 26          79,8              80,5       0,65      0,01     99,34       1
# 27          86,4             225,3       6,96       0,9     92,15       2
# 28          97,8             506,5         20      6,67     73,33       2
# 29          93,9             237,2       0,57      0,76     98,67       2
# ..           ...               ...        ...       ...       ...     ...
# 197         76,9             153,8      25,22      4,43     70,35       1
# 198         96,1             591,0         24         1        75       2
# 199         99,4              33,5       6,61      0,92     92,47       2
# 200         78,2               4,0       4,52      1,08      94,4    None
# 201         92,6             108,9      29,36      6,46     64,18       2
# 202         60,9              10,6      46,15      2,21     51,64       2
# 203         98,5              97,7      23,61     43,06     33,33       2
# 204         98,6             303,5      14,62      9,16     76,22       2
# 205         74,2             123,6      17,86     13,74      68,4       3
# 206         86,5             269,5      30,93      3,31     65,76       3
# 207         98,0              74,6       3,72      0,14     96,14       1
# 208         98,0             269,5       2,33         0     97,67       2
# 209         None              59,3          0         0       100       2
# 210         69,9               3,6      25,88     10,65     63,47       2
# 211         99,7             259,9      56,21      1,61     42,18       3
# 212         77,9             475,3        0,6      2,25     97,15       1
# 213         99,0             543,5      23,46      0,21     76,33       3
# 214         97,0             898,0      19,13      0,22     80,65       3
# 215         98,0             291,4       7,43      0,23     92,34       3
# 216         99,3              62,9      10,83      0,83     88,34       1
# 217         53,0              32,6       2,46      7,38     90,16       2
# 218         93,4             140,1       2,95      0,92     96,13       2
# 219         90,3             187,7      19,97      5,95     74,08       2
# 220         None             652,8      11,76      2,94      85,3       2
# 221         50,0             118,6          5        25        70       2
# 222         None             145,2       16,9     18,97     64,13       3
# 223         None              None       0,02         0     99,98       1
# 224         50,2              37,2       2,78      0,24     96,98       1
# 225         80,6               8,2       7,08      0,03      92,9       2
# 226         90,7              26,8       8,32      0,34     91,34       2
#
#     Birthrate Deathrate Agriculture Industry Service
# 0        46,6     20,34        0,38     0,24    0,38
# 1       15,11      5,22       0,232    0,188   0,579
# 2       17,14      4,61       0,101      0,6   0,298
# 3       22,46      3,27        None     None    None
# 4        8,71      6,25        None     None    None
# 5       45,11      24,2       0,096    0,658   0,246
# 6       14,17      5,34        0,04     0,18    0,78
# 7       16,93      5,37       0,038     0,22   0,743
# 8       16,73      7,55       0,095    0,358   0,547
# 9       12,07      8,23       0,239    0,343   0,418
# 10      11,03      6,68       0,004    0,333   0,663
# 11      12,14      7,51       0,038    0,262     0,7
# 12       8,74      9,76       0,018    0,304   0,678
# 13      20,74      9,75       0,141    0,457   0,402
# 14      17,57      9,05        0,03     0,07     0,9
# 15       17,8      4,14       0,005    0,387   0,608
# 16       29,8      8,27       0,199    0,198   0,603
# 17      12,71      8,67        0,06     0,16    0,78
# 18      11,16     14,02       0,093    0,316   0,591
# 19      10,38     10,27        0,01     0,24   0,749
# 20      28,84      5,72       0,142    0,152   0,612
# 21      38,85     12,22       0,316    0,138   0,546
# 22       11,4      7,74        0,01      0,1    0,89
# 23      33,65      12,7       0,258    0,379   0,363
# 24       23,3      7,53       0,128    0,352    0,52
# 25       8,77      8,27       0,142    0,308    0,55
# 26      23,08      29,5       0,024    0,469   0,507
# 27      16,56      6,17       0,084      0,4   0,516
# 28      14,89      4,42       0,018    0,062    0,92
# 29      18,79      3,45       0,036    0,561   0,403
# ..        ...       ...         ...      ...     ...
# 197     27,76      4,81       0,249     0,23   0,519
# 198     12,56      6,48       0,018    0,259   0,723
# 199     32,65      8,25       0,234    0,286    0,48
# 200     37,71     16,39       0,432    0,172   0,396
# 201     13,87      7,04       0,099    0,441    0,46
# 202     37,01      9,83       0,395    0,204   0,401
# 203     25,37      5,28        0,23     0,27     0,5
# 204      12,9     10,57       0,007     0,57   0,423
# 205     15,52      5,13       0,132    0,318    0,55
# 206     16,62      5,97       0,117    0,298   0,585
# 207     27,61       8,6       0,209     0,38   0,411
# 208     21,84      4,21        None     None    None
# 209     22,18      7,11       0,166    0,272   0,562
# 210     47,35     12,24       0,311    0,222   0,469
# 211      8,82     14,39       0,187    0,452   0,361
# 212     18,96       4,4        0,04    0,585   0,375
# 213     10,71     10,13       0,005    0,237   0,758
# 214     14,14      8,26        0,01    0,204   0,787
# 215     13,91      9,05       0,093    0,311   0,596
# 216     26,36      7,84       0,342    0,229    0,43
# 217     22,72      7,82        0,26     0,12    0,62
# 218     18,71      4,92        0,04    0,419   0,541
# 219     16,86      6,22       0,209     0,41   0,381
# 220     13,96      6,43        0,01     0,19     0,8
# 221      None      None        None     None    None
# 222     31,67      3,92        0,09     0,28    0,63
# 223      None      None        None     None     0,4
# 224     42,89       8,3       0,135    0,472   0,393
# 225        41     19,93        0,22     0,29   0,489
# 226     28,01     21,84       0,179    0,243   0,579
#
# [227 rows x 20 columns]

# %% [markdown]
# We can inspect the schema of the DataFrame.

# %%
countries.printSchema()
# Out:
# root
#  |-- Country: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Population: integer (nullable = true)
#  |-- Area (sq. mi.): integer (nullable = true)
#  |-- Pop. Density (per sq. mi.): string (nullable = true)
#  |-- Coastline (coast/area ratio): string (nullable = true)
#  |-- Net migration: string (nullable = true)
#  |-- Infant mortality (per 1000 births): string (nullable = true)
#  |-- GDP ($ per capita): integer (nullable = true)
#  |-- Literacy (%): string (nullable = true)
#  |-- Phones (per 1000): string (nullable = true)
#  |-- Arable (%): string (nullable = true)
#  |-- Crops (%): string (nullable = true)
#  |-- Other (%): string (nullable = true)
#  |-- Climate: string (nullable = true)
#  |-- Birthrate: string (nullable = true)
#  |-- Deathrate: string (nullable = true)
#  |-- Agriculture: string (nullable = true)
#  |-- Industry: string (nullable = true)
#  |-- Service: string (nullable = true)

# %% [markdown]
# ### Examples of SQL Queries

# %%
countries.createOrReplaceTempView("countries")

# %%
spark.sql("SELECT * FROM countries WHERE Region LIKE '%OCEANIA%'").toPandas()
# Out:
#                   Country                               Region  Population  \
# 0         American Samoa   OCEANIA                                   57794
# 1              Australia   OCEANIA                                20264082
# 2           Cook Islands   OCEANIA                                   21388
# 3                   Fiji   OCEANIA                                  905949
# 4       French Polynesia   OCEANIA                                  274578
# 5                   Guam   OCEANIA                                  171019
# 6               Kiribati   OCEANIA                                  105432
# 7       Marshall Islands   OCEANIA                                   60422
# 8   Micronesia, Fed. St.   OCEANIA                                  108004
# 9                  Nauru   OCEANIA                                   13287
# 10         New Caledonia   OCEANIA                                  219246
# 11           New Zealand   OCEANIA                                 4076140
# 12    N. Mariana Islands   OCEANIA                                   82459
# 13                 Palau   OCEANIA                                   20579
# 14      Papua New Guinea   OCEANIA                                 5670544
# 15                 Samoa   OCEANIA                                  176908
# 16       Solomon Islands   OCEANIA                                  552438
# 17                 Tonga   OCEANIA                                  114689
# 18                Tuvalu   OCEANIA                                   11810
# 19               Vanuatu   OCEANIA                                  208869
# 20     Wallis and Futuna   OCEANIA                                   16025
#
#     Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0              199                      290,4                        58,29
# 1          7686850                        2,6                         0,34
# 2              240                       89,1                        50,00
# 3            18270                       49,6                         6,18
# 4             4167                       65,9                        60,60
# 5              541                      316,1                        23,20
# 6              811                      130,0                       140,94
# 7            11854                        5,1                         3,12
# 8              702                      153,9                       870,66
# 9               21                      632,7                       142,86
# 10           19060                       11,5                        11,83
# 11          268680                       15,2                         5,63
# 12             477                      172,9                       310,69
# 13             458                       44,9                       331,66
# 14          462840                       12,3                         1,11
# 15            2944                       60,1                        13,69
# 16           28450                       19,4                        18,67
# 17             748                      153,3                        56,02
# 18              26                      454,2                        92,31
# 19           12200                       17,1                        20,72
# 20             274                       58,5                        47,08
#
#    Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         -20,71                               9,27                8000
# 1           3,98                               4,69               29000
# 2           None                               None                5000
# 3          -3,14                              12,62                5800
# 4           2,94                               8,44               17500
# 5              0                               6,94               21000
# 6              0                              48,52                 800
# 7          -6,04                              29,45                1600
# 8         -20,99                              30,21                2000
# 9              0                               9,95                5000
# 10             0                               7,72               15000
# 11          4,05                               5,85               21600
# 12          9,61                               7,11               12500
# 13          2,85                              14,84                9000
# 14             0                              51,45                2200
# 15         -11,7                              27,71                5600
# 16             0                              21,29                1700
# 17             0                              12,62                2200
# 18             0                              20,03                1100
# 19             0                              55,16                2900
# 20          None                               None                3700
#
#    Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0          97,0             259,5         10        15        75       2
# 1         100,0             565,5       6,55      0,04     93,41       1
# 2          95,0             289,9      17,39     13,04     69,57       2
# 3          93,7             112,6      10,95      4,65      84,4       2
# 4          98,0             194,5       0,82      5,46     93,72       2
# 5          99,0             492,0       9,09     16,36     74,55       2
# 6          None              42,7       2,74     50,68     46,58       2
# 7          93,7              91,2      16,67     38,89     44,44       2
# 8          89,0             114,8       5,71     45,71     48,58       2
# 9          None             143,0          0         0       100       2
# 10         91,0             252,2       0,38      0,33     99,29       2
# 11         99,0             441,7        5,6      6,99     87,41       3
# 12         97,0             254,7      13,04      4,35     82,61       2
# 13         92,0             325,6        8,7      4,35     86,95       2
# 14         64,6              10,9       0,46      1,44      98,1       2
# 15         99,7              75,2       21,2     24,38     54,42       2
# 16         None              13,4       0,64         2     97,36       2
# 17         98,5              97,7      23,61     43,06     33,33       2
# 18         None              59,3          0         0       100       2
# 19         53,0              32,6       2,46      7,38     90,16       2
# 20         50,0             118,6          5        25        70       2
#
#    Birthrate Deathrate Agriculture Industry Service
# 0      22,46      3,27        None     None    None
# 1      12,14      7,51       0,038    0,262     0,7
# 2         21      None       0,151    0,096   0,753
# 3      22,55      5,65       0,089    0,135   0,776
# 4      16,68      4,69       0,031     0,19   0,769
# 5      18,79      4,48        None     None    None
# 6      30,65      8,26       0,089    0,242   0,668
# 7      33,05      4,78       0,317    0,149   0,534
# 8      24,68      4,75       0,289    0,152   0,559
# 9      24,76       6,7        None     None    None
# 10     18,11      5,69        0,15    0,088   0,762
# 11     13,76      7,53       0,043    0,273   0,684
# 12     19,43      2,29        None     None    None
# 13     18,03       6,8       0,062     0,12   0,818
# 14     29,36      7,25       0,353    0,381   0,266
# 15     16,43      6,62       0,114    0,584   0,302
# 16     30,01      3,92        0,42     0,11    0,47
# 17     25,37      5,28        0,23     0,27     0,5
# 18     22,18      7,11       0,166    0,272   0,562
# 19     22,72      7,82        0,26     0,12    0,62
# 20      None      None        None     None    None

# %% [markdown]
# ### Queries using PySpark DSL
#
# DSL = Domain Specific Language - API similar to natural or other language, implemented as library in another language.

# %% [markdown]
# List all the countries with the population > 38 million

# %%
countries.filter((col("Population") > 38000000)).orderBy("Population").toPandas()
# Out:
#               Country                               Region  Population  \
# 0             Poland   EASTERN EUROPE                         38536869
# 1          Argentina               LATIN AMER. & CARIB        39921833
# 2              Spain   WESTERN EUROPE                         40397842
# 3              Sudan   SUB-SAHARAN AFRICA                     41236378
# 4           Colombia               LATIN AMER. & CARIB        43593035
# 5       South Africa   SUB-SAHARAN AFRICA                     44187637
# 6            Ukraine                  C.W. OF IND. STATES     46710816
# 7              Burma         ASIA (EX. NEAR EAST)             47382633
# 8       Korea, South         ASIA (EX. NEAR EAST)             48846823
# 9              Italy   WESTERN EUROPE                         58133509
# 10    United Kingdom   WESTERN EUROPE                         60609153
# 11            France   WESTERN EUROPE                         60876136
# 12  Congo, Dem. Rep.   SUB-SAHARAN AFRICA                     62660551
# 13          Thailand         ASIA (EX. NEAR EAST)             64631595
# 14              Iran         ASIA (EX. NEAR EAST)             68688433
# 15            Turkey   NEAR EAST                              70413958
# 16          Ethiopia   SUB-SAHARAN AFRICA                     74777981
# 17             Egypt   NORTHERN AFRICA                        78887007
# 18           Germany   WESTERN EUROPE                         82422299
# 19           Vietnam         ASIA (EX. NEAR EAST)             84402966
# 20       Philippines         ASIA (EX. NEAR EAST)             89468677
# 21            Mexico               LATIN AMER. & CARIB       107449525
# 22             Japan         ASIA (EX. NEAR EAST)            127463611
# 23           Nigeria   SUB-SAHARAN AFRICA                    131859731
# 24            Russia                  C.W. OF IND. STATES    142893540
# 25        Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 26          Pakistan         ASIA (EX. NEAR EAST)            165803560
# 27            Brazil               LATIN AMER. & CARIB       188078227
# 28         Indonesia         ASIA (EX. NEAR EAST)            245452739
# 29     United States   NORTHERN AMERICA                      298444215
# 30             India         ASIA (EX. NEAR EAST)           1095351995
# 31             China         ASIA (EX. NEAR EAST)           1313973713
#
#     Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0           312685                      123,3                         0,16
# 1          2766890                       14,4                         0,18
# 2           504782                       80,0                         0,98
# 3          2505810                       16,5                         0,03
# 4          1138910                       38,3                         0,28
# 5          1219912                       36,2                         0,23
# 6           603700                       77,4                         0,46
# 7           678500                       69,8                         0,28
# 8            98480                      496,0                         2,45
# 9           301230                      193,0                         2,52
# 10          244820                      247,6                         5,08
# 11          547030                      111,3                         0,63
# 12         2345410                       26,7                         0,00
# 13          514000                      125,7                         0,63
# 14         1648000                       41,7                         0,15
# 15          780580                       90,2                         0,92
# 16         1127127                       66,3                         0,00
# 17         1001450                       78,8                         0,24
# 18          357021                      230,9                         0,67
# 19          329560                      256,1                         1,05
# 20          300000                      298,2                        12,10
# 21         1972550                       54,5                         0,47
# 22          377835                      337,4                         7,87
# 23          923768                      142,7                         0,09
# 24        17075200                        8,4                         0,22
# 25          144000                     1023,4                         0,40
# 26          803940                      206,2                         0,13
# 27         8511965                       22,1                         0,09
# 28         1919440                      127,9                         2,85
# 29         9631420                       31,0                         0,21
# 30         3287590                      333,2                         0,21
# 31         9596960                      136,9                         0,15
#
#    Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          -0,49                               8,51               11100
# 1           0,61                              15,18               11200
# 2           0,99                               4,42               22000
# 3          -0,02                               62,5                1900
# 4          -0,31                              20,97                6300
# 5          -0,29                              61,81               10700
# 6          -0,39                              20,34                5400
# 7           -1,8                              67,24                1800
# 8              0                               7,05               17800
# 9           2,07                               5,94               26700
# 10          2,19                               5,16               27700
# 11          0,66                               4,26               27600
# 12             0                              94,69                 700
# 13             0                              20,48                7400
# 14         -0,84                              41,58                7000
# 15             0                              41,04                6700
# 16             0                              95,32                 700
# 17         -0,22                              32,59                4000
# 18          2,18                               4,16               27600
# 19         -0,45                              25,95                2500
# 20          -1,5                              23,51                4600
# 21         -4,87                              20,91                9000
# 22             0                               3,26               28200
# 23          0,26                               98,8                 900
# 24          1,02                              15,39                8900
# 25         -0,71                               62,6                1900
# 26         -2,77                              72,44                2100
# 27         -0,03                              29,61                7600
# 28             0                               35,6                3200
# 29          3,41                                6,5               37800
# 30         -0,07                              56,29                2900
# 31          -0,4                              24,18                5000
#
#    Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0          99,8             306,3      45,91      1,12     52,97       3
# 1          97,1             220,4      12,31      0,48     87,21       3
# 2          97,9             453,5      26,07      9,87     64,06       3
# 3          61,1              16,3       6,83      0,18     92,99       2
# 4          92,5             176,2       2,42      1,67     95,91       2
# 5          86,4             107,0      12,08      0,79     87,13       1
# 6          99,7             259,9      56,21      1,61     42,18       3
# 7          85,3              10,1      15,19      0,97     83,84       2
# 8          97,9             486,1      17,18      1,95     80,87       3
# 9          98,6             430,9      27,79      9,53     62,68    None
# 10         99,0             543,5      23,46      0,21     76,33       3
# 11         99,0             586,4      33,53      2,07      64,4       4
# 12         65,5               0,2       2,96      0,52     96,52       2
# 13         92,6             108,9      29,36      6,46     64,18       2
# 14         79,4             276,4       8,72      1,39     89,89       1
# 15         86,5             269,5      30,93      3,31     65,76       3
# 16         42,7               8,2      10,71      0,75     88,54       2
# 17         57,7             131,8       2,87      0,48     96,65       1
# 18         99,0             667,9      33,85      0,59     65,56       3
# 19         90,3             187,7      19,97      5,95     74,08       2
# 20         92,6              38,4      18,95     16,77     64,28       2
# 21         92,2             181,6      12,99      1,31      85,7     1,5
# 22         99,0             461,2      12,19      0,96     86,85       3
# 23         68,0               9,3      31,29      2,96     65,75     1,5
# 24         99,6             280,6       7,33      0,11     92,56    None
# 25         43,1               7,3      62,11      3,07     34,82       2
# 26         45,7              31,8      27,87      0,87     71,26       1
# 27         86,4             225,3       6,96       0,9     92,15       2
# 28         87,9              52,0      11,32      7,23     81,45       2
# 29         97,0             898,0      19,13      0,22     80,65       3
# 30         59,5              45,4       54,4      2,74     42,86     2,5
# 31         90,9             266,7       15,4      1,25     83,35     1,5
#
#    Birthrate Deathrate Agriculture Industry Service
# 0       9,85      9,89        0,05    0,311    0,64
# 1      16,73      7,55       0,095    0,358   0,547
# 2      10,06      9,72        0,04    0,295   0,665
# 3      34,53      8,97       0,387    0,203    0,41
# 4      20,48      5,58       0,125    0,342   0,533
# 5       18,2        22       0,025    0,303   0,671
# 6       8,82     14,39       0,187    0,452   0,361
# 7      17,91      9,83       0,564    0,082   0,353
# 8         10      5,85       0,033    0,403   0,563
# 9       8,72      10,4       0,021    0,291   0,688
# 10     10,71     10,13       0,005    0,237   0,758
# 11     11,99      9,14       0,022    0,214   0,764
# 12     43,69     13,27        0,55     0,11    0,34
# 13     13,87      7,04       0,099    0,441    0,46
# 14        17      5,55       0,116    0,424    0,46
# 15     16,62      5,97       0,117    0,298   0,585
# 16     37,98     14,86       0,475    0,099   0,426
# 17     22,94      5,23       0,149    0,357   0,493
# 18      8,25     10,62       0,009    0,296   0,695
# 19     16,86      6,22       0,209     0,41   0,381
# 20     24,89      5,41       0,144    0,326    0,53
# 21     20,69      4,74       0,038    0,259   0,702
# 22      9,37      9,16       0,017    0,258   0,725
# 23     40,43     16,94       0,269    0,487   0,244
# 24      9,95     14,65       0,054    0,371   0,575
# 25      29,8      8,27       0,199    0,198   0,603
# 26     29,74      8,23       0,216    0,251   0,533
# 27     16,56      6,17       0,084      0,4   0,516
# 28     20,34      6,25       0,134    0,458   0,408
# 29     14,14      8,26        0,01    0,204   0,787
# 30     22,01      8,18       0,186    0,276   0,538
# 31     13,25      6,97       0,125    0,473   0,403

# %% [markdown]
# Select all the countries from Europe

# %%
countries.select("Country", "Population").where(col("Region").like("%EUROPE%")).show()
# Out:
# +--------------------+----------+
# |             Country|Population|
# +--------------------+----------+
# |            Albania |   3581655|
# |            Andorra |     71201|
# |            Austria |   8192880|
# |            Belgium |  10379067|
# |Bosnia & Herzegov...|   4498976|
# |           Bulgaria |   7385367|
# |            Croatia |   4494749|
# |     Czech Republic |  10235455|
# |            Denmark |   5450661|
# |      Faroe Islands |     47246|
# |            Finland |   5231372|
# |             France |  60876136|
# |            Germany |  82422299|
# |          Gibraltar |     27928|
# |             Greece |  10688058|
# |           Guernsey |     65409|
# |            Hungary |   9981334|
# |            Iceland |    299388|
# |            Ireland |   4062235|
# |        Isle of Man |     75441|
# +--------------------+----------+
# only showing top 20 rows

# %% [markdown]
# Conditions in `where` clause can contain logical expressions.

# %%
countries.select("Country", "Population")\
.where((col("Region").like("%EUROPE%")) & (col("Population")> 10000000)).show()
# Out:
# +---------------+----------+
# |        Country|Population|
# +---------------+----------+
# |       Belgium |  10379067|
# |Czech Republic |  10235455|
# |        France |  60876136|
# |       Germany |  82422299|
# |        Greece |  10688058|
# |         Italy |  58133509|
# |   Netherlands |  16491461|
# |        Poland |  38536869|
# |      Portugal |  10605870|
# |       Romania |  22303552|
# |         Spain |  40397842|
# |United Kingdom |  60609153|
# +---------------+----------+

# %% [markdown]
# ### Aggregation
#
# We can run aggregations with predefined functions (faster!):

# %%
from pyspark.sql.functions import sum

# %%
pd_countries = countries.select("Region", "Population").groupBy("Region").agg(sum("Population")).toPandas()

# %%
pd_countries
# Out:
#                                  Region  sum(Population)
# 0   BALTICS                                      7184974
# 1                  C.W. OF IND. STATES         280081548
# 2         ASIA (EX. NEAR EAST)                3687982236
# 3   WESTERN EUROPE                             396339998
# 4   NORTHERN AMERICA                           331672307
# 5   NEAR EAST                                  195068377
# 6   EASTERN EUROPE                             119914717
# 7   OCEANIA                                     33131662
# 8   SUB-SAHARAN AFRICA                         749437000
# 9   NORTHERN AFRICA                            161407133
# 10              LATIN AMER. & CARIB            561824599

# %% [markdown]
# We can make the column name look better, by using `alias`:

# %%
pd_countries = countries.select("Region", "Population").groupBy("Region").agg(sum("Population").alias('Total')).toPandas()

# %%
pd_countries
# Out:
#                                  Region       Total
# 0   BALTICS                                 7184974
# 1                  C.W. OF IND. STATES    280081548
# 2         ASIA (EX. NEAR EAST)           3687982236
# 3   WESTERN EUROPE                        396339998
# 4   NORTHERN AMERICA                      331672307
# 5   NEAR EAST                             195068377
# 6   EASTERN EUROPE                        119914717
# 7   OCEANIA                                33131662
# 8   SUB-SAHARAN AFRICA                    749437000
# 9   NORTHERN AFRICA                       161407133
# 10              LATIN AMER. & CARIB       561824599

# %% [markdown]
# ### Plot examples
# Pandas DataFrames are useful for plotting using MatPlotLib:

# %%
pd_countries.plot(x='Region', y='Total',kind='bar', figsize=(10, 6))

# %% [markdown]
# ## User defined functions for data manipulation
# Our `countries` DataFrame has some problems:
#  * missing values
#  * some numbers use comma instead of point as floating point separator (e.g. Literacy  = 99,4)
#
# We can clean the data using User Defined Functions (UDF)

# %%
from pyspark.sql.types import FloatType
from pyspark.sql.functions import udf

# %% [markdown]
# Define a Python function which coverts numbers with commas to `float`

# %%
def to_float (s) :
   return float(s.replace(',','.'))

# %% [markdown]
# Test that it works:

# %%
to_float('0,99')
# Out:
# 0.99

# %% [markdown]
# Now define a Spark UDF:

# %%
float_udf = udf(to_float , FloatType())

# %% [markdown]
# Before we can use the UDF, we need to remove empty rows. Otherwise our UDF will fail.

# %%
full_countries = countries.select('Country', 'Population', 'Literacy (%)', 'GDP ($ per capita)').na.drop()

# %% [markdown]
# We can now apply the new UDF to the Data Frame:

# %%
full_countries = full_countries.withColumn("Literacy", float_udf("Literacy (%)"))

# %%
full_countries.show(50)
# Out:
# +--------------------+----------+------------+------------------+--------+
# |             Country|Population|Literacy (%)|GDP ($ per capita)|Literacy|
# +--------------------+----------+------------+------------------+--------+
# |        Afghanistan |  31056997|        36,0|               700|    36.0|
# |            Albania |   3581655|        86,5|              4500|    86.5|
# |            Algeria |  32930091|        70,0|              6000|    70.0|
# |     American Samoa |     57794|        97,0|              8000|    97.0|
# |            Andorra |     71201|       100,0|             19000|   100.0|
# |             Angola |  12127071|        42,0|              1900|    42.0|
# |           Anguilla |     13477|        95,0|              8600|    95.0|
# |  Antigua & Barbuda |     69108|        89,0|             11000|    89.0|
# |          Argentina |  39921833|        97,1|             11200|    97.1|
# |            Armenia |   2976372|        98,6|              3500|    98.6|
# |              Aruba |     71891|        97,0|             28000|    97.0|
# |          Australia |  20264082|       100,0|             29000|   100.0|
# |            Austria |   8192880|        98,0|             30000|    98.0|
# |         Azerbaijan |   7961619|        97,0|              3400|    97.0|
# |       Bahamas, The |    303770|        95,6|             16700|    95.6|
# |            Bahrain |    698585|        89,1|             16900|    89.1|
# |         Bangladesh | 147365352|        43,1|              1900|    43.1|
# |           Barbados |    279912|        97,4|             15700|    97.4|
# |            Belarus |  10293011|        99,6|              6100|    99.6|
# |            Belgium |  10379067|        98,0|             29100|    98.0|
# |             Belize |    287730|        94,1|              4900|    94.1|
# |              Benin |   7862944|        40,9|              1100|    40.9|
# |            Bermuda |     65773|        98,0|             36000|    98.0|
# |             Bhutan |   2279723|        42,2|              1300|    42.2|
# |            Bolivia |   8989046|        87,2|              2400|    87.2|
# |           Botswana |   1639833|        79,8|              9000|    79.8|
# |             Brazil | 188078227|        86,4|              7600|    86.4|
# | British Virgin Is. |     23098|        97,8|             16000|    97.8|
# |             Brunei |    379444|        93,9|             18600|    93.9|
# |           Bulgaria |   7385367|        98,6|              7600|    98.6|
# |       Burkina Faso |  13902972|        26,6|              1100|    26.6|
# |              Burma |  47382633|        85,3|              1800|    85.3|
# |            Burundi |   8090068|        51,6|               600|    51.6|
# |           Cambodia |  13881427|        69,4|              1900|    69.4|
# |           Cameroon |  17340702|        79,0|              1800|    79.0|
# |             Canada |  33098932|        97,0|             29800|    97.0|
# |         Cape Verde |    420979|        76,6|              1400|    76.6|
# |     Cayman Islands |     45436|        98,0|             35000|    98.0|
# |Central African R...|   4303356|        51,0|              1100|    51.0|
# |               Chad |   9944201|        47,5|              1200|    47.5|
# |              Chile |  16134219|        96,2|              9900|    96.2|
# |              China |1313973713|        90,9|              5000|    90.9|
# |           Colombia |  43593035|        92,5|              6300|    92.5|
# |            Comoros |    690948|        56,5|               700|    56.5|
# |   Congo, Dem. Rep. |  62660551|        65,5|               700|    65.5|
# |Congo, Repub. of ...|   3702314|        83,8|               700|    83.8|
# |       Cook Islands |     21388|        95,0|              5000|    95.0|
# |         Costa Rica |   4075261|        96,0|              9100|    96.0|
# |      Cote d'Ivoire |  17654843|        50,9|              1400|    50.9|
# |            Croatia |   4494749|        98,5|             10600|    98.5|
# +--------------------+----------+------------+------------------+--------+
# only showing top 50 rows

# %%
full_countries.where((col("Literacy") < 50) & (col("GDP ($ per capita)") > 700)).show()
# Out:
# +--------------+----------+------------+------------------+--------+
# |       Country|Population|Literacy (%)|GDP ($ per capita)|Literacy|
# +--------------+----------+------------+------------------+--------+
# |       Angola |  12127071|        42,0|              1900|    42.0|
# |   Bangladesh | 147365352|        43,1|              1900|    43.1|
# |        Benin |   7862944|        40,9|              1100|    40.9|
# |       Bhutan |   2279723|        42,2|              1300|    42.2|
# | Burkina Faso |  13902972|        26,6|              1100|    26.6|
# |         Chad |   9944201|        47,5|              1200|    47.5|
# |  Gambia, The |   1641564|        40,1|              1700|    40.1|
# |       Guinea |   9690222|        35,9|              2100|    35.9|
# |Guinea-Bissau |   1442029|        42,4|               800|    42.4|
# |         Iraq |  26783383|        40,4|              1500|    40.4|
# |         Mali |  11716829|        46,4|               900|    46.4|
# |   Mauritania |   3177388|        41,7|              1800|    41.7|
# |   Mozambique |  19686505|        47,8|              1200|    47.8|
# |        Nepal |  28287147|        45,2|              1400|    45.2|
# |        Niger |  12525094|        17,6|               800|    17.6|
# |     Pakistan | 165803560|        45,7|              2100|    45.7|
# |      Senegal |  11987121|        40,2|              1600|    40.2|
# +--------------+----------+------------+------------------+--------+

# %%
full_countries.toPandas().plot(x="Literacy",y="GDP ($ per capita)",kind="scatter",figsize=(10, 6))

# %% [markdown]
# # Exercises

# %%
# Read in the airports data
arp = spark.read.csv("airportsAll.csv",inferSchema=True,header=False).\
toDF("id","airport","city","country","iata","icao","latitude","longitude","altitude","timezone","dst","tz_timezone","type","data_source")

arp.limit(5).toPandas()
# Out:
#    id                                      airport          city  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             country iata  icao  latitude   longitude  altitude timezone dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282       10   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20       10   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388       10   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239       10   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146       10   U
#
#             tz_timezone     type  data_source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %% [markdown]
# 1. Print all the airports that are to the North from Krakow

# %%
krkLat =  arp.filter(col("city") == "Krakow").select('latitude').collect()[0][0]
arp.filter(col("latitude") > krkLat).limit(5).toPandas()
# Out:
#    id                  airport          city    country iata  icao   latitude  \
# 0   7       Narsarsuaq Airport  Narssarssuaq  Greenland  UAK  BGBW  61.160500
# 1   8  Godthaab / Nuuk Airport      Godthaab  Greenland  GOH  BGGH  64.190903
# 2   9    Kangerlussuaq Airport   Sondrestrom  Greenland  SFJ  BGSF  67.012222
# 3  10           Thule Air Base         Thule  Greenland  THU  BGTL  76.531197
# 4  11         Akureyri Airport      Akureyri    Iceland  AEY  BIAR  65.660004
#
#    longitude  altitude timezone dst         tz_timezone     type  data_source
# 0 -45.425999       112       -3   E     America/Godthab  airport  OurAirports
# 1 -51.678101       283       -3   E     America/Godthab  airport  OurAirports
# 2 -50.711603       165       -3   E     America/Godthab  airport  OurAirports
# 3 -68.703201       251       -4   E       America/Thule  airport  OurAirports
# 4 -18.072701         6        0   N  Atlantic/Reykjavik  airport  OurAirports

# %% [markdown]
# 2. For each state, find the airport which is closest to the South Pole.

# %%
airGrupByC =  arp.groupBy("country").min("latitude")
#airGrupByC.toPandas()
arp.join(airGrupByC,(airGrupByC["min(latitude)"] == arp["latitude"]) & (airGrupByC["country"] == arp["country"])).limit(5).toPandas()
# Out:
#     id                 airport            city       country iata  icao  \
# 0   20  Vestmannaeyjar Airport  Vestmannaeyjar       Iceland  VEY  BIVM
# 1  113         Windsor Airport         Windsor        Canada  YQG  CYQG
# 2  245       Cadjehoun Airport         Cotonou         Benin  COO  DBBB
# 3  247  Bobo Dioulasso Airport  Bobo-dioulasso  Burkina Faso  BOY  DFOO
# 4  252        Takoradi Airport        Takoradi         Ghana  TKD  DGTK
#
#     latitude  longitude  altitude timezone dst         tz_timezone     type  \
# 0  63.424301 -20.278900       326        0   N  Atlantic/Reykjavik  airport
# 1  42.275600 -82.955597       622       -5   A     America/Toronto  airport
# 2   6.357230   2.384350        19        1   N   Africa/Porto-Novo  airport
# 3  11.160100  -4.330970      1511        0   N  Africa/Ouagadougou  airport
# 4   4.896060  -1.774760        21        0   N        Africa/Accra  airport
#
#    data_source       country  min(latitude)
# 0  OurAirports       Iceland      63.424301
# 1  OurAirports        Canada      42.275600
# 2  OurAirports         Benin       6.357230
# 3  OurAirports  Burkina Faso      11.160100
# 4  OurAirports         Ghana       4.896060

# %% [markdown]
# 3. Plot the coordinates of all the airports. Bonus: plot on the map.

# %%
arp.toPandas().plot(x="longitude",y="latitude",kind="scatter")

# %% [markdown]
# 4. Plot GDP vs. Phones for all countries in Asia.

# %%
asia =  countries.filter(col("Region").like('ASIA%'))
asia = asia.select([col('Phones (per 1000)'),col('GDP ($ per capita)')])
asia = asia.na.drop()
asia = asia.withColumn("Phones", float_udf("Phones (per 1000)"))
asia.toPandas().plot(x="GDP ($ per capita)",y="Phones",kind="scatter")

# %% [markdown]
# 5. Extra: Na wykresie scatterplot narysuj zależność liczby lotnisk od powierzchni kraju.

# %%
from pyspark.sql.functions import trim

countryAirCount =arp.groupBy("country").count()
countryAirCount = countryAirCount.withColumn("country", trim(countryAirCount.country))
countryAirCount=countryAirCount.replace(['Korea, South', 'Korea, North'], ['South Korea', 'North Korea'], 'Country')
countries = countries.withColumn("Country", trim(countries.Country))

countriesWirthAirportCount= countries.join(countryAirCount,countries["Country"] == countryAirCount["country"])

countriesWirthAirportCount.toPandas().plot(x="Area (sq. mi.)",y="count",kind="scatter")

# %% [markdown]
# 5. Plot Infant mortality vs. Literacy for top 30 richest and top 30 poorest countries.

# %%
countries.toPandas()
topRichest = countries.where(col('GDP ($ per capita)') > 0).orderBy(col('GDP ($ per capita)'),ascending=False).limit(30)
topPoorest = countries.where(col('GDP ($ per capita)') > 0).orderBy(col('GDP ($ per capita)')).limit(30)
dataToPlot = topRichest.unionAll(topPoorest)
dataToPlot = dataToPlot.select([col('Deathrate'),col('Literacy (%)')])
dataToPlot = dataToPlot.na.drop() 
dataToPlot = dataToPlot.withColumn("Literacy", float_udf("Literacy (%)"))
dataToPlot = dataToPlot.withColumn("DeathrateNum", float_udf("Deathrate"))
dataToPlot.toPandas().plot(x="DeathrateNum",y="Literacy",kind="scatter")
#countries.toPandas()

# %% [markdown]
# # Useful information
#
#  * https://spark.apache.org/docs/latest/quick-start.html
#  * https://spark.apache.org/docs/latest/sql-programming-guide.html
#  * https://pandas.pydata.org/pandas-docs/stable/visualization.html
